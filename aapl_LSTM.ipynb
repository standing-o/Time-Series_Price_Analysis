# %% [markdown]
# # AAPL price forecasting
# - This is an ipynb file created in colab environment.
# - Runtime : GPU
# - stacked LSTM

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append('/content/drive/MyDrive/Github/Time-series_price_analysis')

# %%
# !ls /content/drive/MyDrive/Github/Time-series_price_analysis/*.py
# Out:
# /content/drive/MyDrive/Github/Time-series_price_analysis/make_dataset.py

# %% [markdown]
# ## 0. Import Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import random as rn
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import ModelCheckpoint

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

import tensorflow as tf
import os

from make_dataset import time_transform, make_input

# %%
# reproducibility
seed_num = 42
rn.seed(seed_num)
tf.random.set_seed(seed_num)
os.environ['PYTHONHASHSEED']=str(seed_num)

from keras import backend as K
session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
K.set_session(sess)

# %% [markdown]
# ## 1. Load and visualize dataset

# %%
df = pd.read_csv("/content/drive/MyDrive/Github/Time-series_price_analysis/dataset/AAPL.csv")
df.head()
# Out:
#            Date   Price    Open    High     Low    Vol. Change %
# 0  Mar 25, 2022  174.73  173.90  175.27  172.77  73.63M    0.38%
# 1  Mar 24, 2022  174.07  171.06  174.14  170.21  89.68M    2.27%
# 2  Mar 23, 2022  170.21  167.99  172.64  167.65  97.30M    0.82%
# 3  Mar 22, 2022  168.82  165.51  169.42  164.91  80.94M    2.08%
# 4  Mar 21, 2022  165.38  163.51  166.35  163.01  95.81M    0.85%

# %%
df.tail()
# Out:
#               Date  Price   Open   High    Low     Vol. Change %
# 2534  Mar 02, 2012  19.47  19.44  19.53  19.38  431.71M    0.10%
# 2535  Mar 01, 2012  19.45  19.58  19.58  19.24  683.25M    0.41%
# 2536  Feb 29, 2012  19.37  19.34  19.56  19.13  952.00M    1.31%
# 2537  Feb 28, 2012  19.12  18.86  19.12  18.78  600.39M    1.81%
# 2538  Feb 27, 2012  18.78  18.62  18.87  18.44  547.58M    0.64%

# %%
df['Date'] = df['Date'].apply(lambda x: time_transform(x))
dataset = df.sort_values('Date').reset_index(drop=True)

# %%
print("Shape of dataset :", dataset.shape)
dataset.head()
# Out:
# Shape of dataset : (2539, 7)
#          Date  Price   Open   High    Low     Vol. Change %
# 0  2012-02-27  18.78  18.62  18.87  18.44  547.58M    0.64%
# 1  2012-02-28  19.12  18.86  19.12  18.78  600.39M    1.81%
# 2  2012-02-29  19.37  19.34  19.56  19.13  952.00M    1.31%
# 3  2012-03-01  19.45  19.58  19.58  19.24  683.25M    0.41%
# 4  2012-03-02  19.47  19.44  19.53  19.38  431.71M    0.10%

# %%
date = dataset['Date'].values
close = dataset['Price'].values

# %% [markdown]
# ## 2. Preprocessing

# %% [markdown]
# - Min-max scaling

# %%
scaler = MinMaxScaler(feature_range=(0,1))
scaled_close = scaler.fit_transform(np.array(close).reshape(-1,1))

# %%
print(scaled_close)
# Out:
# [[0.02873974]
#  [0.03076282]
#  [0.03225039]
#  ...
#  [0.92978698]
#  [0.95275497]
#  [0.95668214]]

# %% [markdown]
# - Split train and test dataset

# %%
train_size = int(len(close)*0.795)
val_size = len(close)-train_size
train_data, val_data = scaled_close[0:train_size,:], scaled_close[train_size:len(close),:1]

# %%
train_size,val_size
# Out:
# (2018, 521)

# %%
time_step = 1
X_train, y_train = make_input(train_data, time_step)
X_val, y_val = make_input(val_data, time_step)

# %%
print("X train shape :", X_train.shape)
print("y train shape :", y_train.shape)
print("X val shape :", X_val.shape)
print("y val shape :", y_val.shape)
# Out:
# X train shape : (2016, 1)
# y train shape : (2016,)
# X val shape : (519, 1)
# y val shape : (519,)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1] , 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1] , 1)

print("X train shape :", X_train.shape)
print("X val shape :", X_val.shape)
# Out:
# X train shape : (2016, 1, 1)
# X val shape : (519, 1, 1)

# %% [markdown]
# ## 3. Modeling - LSTM

# %%
model = Sequential()

model.add(LSTM(50, return_sequences=True,input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1, kernel_initializer=tf.keras.initializers.glorot_uniform(seed=seed_num)))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 1, 50)             10400
#
#  lstm_1 (LSTM)               (None, 1, 50)             20200
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
adam = Adam(learning_rate=0.001)
chk = ModelCheckpoint('/content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl', monitor = 'val_loss', save_best_only = True, mode = 'min', verbose = 1)
model.compile(loss='mse', optimizer = adam)

# %%
# %%time
hist = model.fit(X_train, y_train, validation_data=(X_val, y_val), callbacks=[chk], epochs=30, batch_size = 64, verbose = 1, shuffle = False)
# Out:
# Epoch 1/100
# 28/32 [=========================>....] - ETA: 0s - loss: 0.0035
# Epoch 1: val_loss improved from inf to 0.28212, saving model to /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl
# WARNING:absl:Found untraced functions such as lstm_cell_12_layer_call_fn, lstm_cell_12_layer_call_and_return_conditional_losses, lstm_cell_13_layer_call_fn, lstm_cell_13_layer_call_and_return_conditional_losses, lstm_cell_14_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7376369550> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7347a0d990> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7344e2ba90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 32/32 [==============================] - 24s 606ms/step - loss: 0.0056 - val_loss: 0.2821
# Epoch 2/100
# 28/32 [=========================>....] - ETA: 0s - loss: 0.0087
# Epoch 2: val_loss did not improve from 0.28212
# 32/32 [==============================] - 0s 10ms/step - loss: 0.0109 - val_loss: 0.3180
# Epoch 3/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.0067
# Epoch 3: val_loss did not improve from 0.28212
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0077 - val_loss: 0.3033
# Epoch 4/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.0068
# Epoch 4: val_loss did not improve from 0.28212
# 32/32 [==============================] - 0s 14ms/step - loss: 0.0076 - val_loss: 0.2864
# Epoch 5/100
# 29/32 [==========================>...] - ETA: 0s - loss: 0.0054
# Epoch 5: val_loss improved from 0.28212 to 0.26256, saving model to /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl
# WARNING:absl:Found untraced functions such as lstm_cell_12_layer_call_fn, lstm_cell_12_layer_call_and_return_conditional_losses, lstm_cell_13_layer_call_fn, lstm_cell_13_layer_call_and_return_conditional_losses, lstm_cell_14_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7376369550> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7347a0d990> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7344e2ba90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 32/32 [==============================] - 36s 1s/step - loss: 0.0074 - val_loss: 0.2626
# Epoch 6/100
# 30/32 [===========================>..] - ETA: 0s - loss: 0.0053
# Epoch 6: val_loss improved from 0.26256 to 0.22437, saving model to /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl
# WARNING:absl:Found untraced functions such as lstm_cell_12_layer_call_fn, lstm_cell_12_layer_call_and_return_conditional_losses, lstm_cell_13_layer_call_fn, lstm_cell_13_layer_call_and_return_conditional_losses, lstm_cell_14_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7376369550> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7347a0d990> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7344e2ba90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 32/32 [==============================] - 19s 622ms/step - loss: 0.0068 - val_loss: 0.2244
# Epoch 7/100
# 27/32 [========================>.....] - ETA: 0s - loss: 0.0047
# Epoch 7: val_loss improved from 0.22437 to 0.16476, saving model to /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl
# WARNING:absl:Found untraced functions such as lstm_cell_12_layer_call_fn, lstm_cell_12_layer_call_and_return_conditional_losses, lstm_cell_13_layer_call_fn, lstm_cell_13_layer_call_and_return_conditional_losses, lstm_cell_14_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7376369550> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7347a0d990> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7344e2ba90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 32/32 [==============================] - 20s 633ms/step - loss: 0.0060 - val_loss: 0.1648
# Epoch 8/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.0044
# Epoch 8: val_loss improved from 0.16476 to 0.08091, saving model to /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl
# WARNING:absl:Found untraced functions such as lstm_cell_12_layer_call_fn, lstm_cell_12_layer_call_and_return_conditional_losses, lstm_cell_13_layer_call_fn, lstm_cell_13_layer_call_and_return_conditional_losses, lstm_cell_14_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7376369550> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7347a0d990> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7344e2ba90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 32/32 [==============================] - 19s 609ms/step - loss: 0.0047 - val_loss: 0.0809
# Epoch 9/100
# 27/32 [========================>.....] - ETA: 0s - loss: 0.0029
# Epoch 9: val_loss improved from 0.08091 to 0.00701, saving model to /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl
# WARNING:absl:Found untraced functions such as lstm_cell_12_layer_call_fn, lstm_cell_12_layer_call_and_return_conditional_losses, lstm_cell_13_layer_call_fn, lstm_cell_13_layer_call_and_return_conditional_losses, lstm_cell_14_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7376369550> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7347a0d990> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7344e2ba90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 32/32 [==============================] - 27s 856ms/step - loss: 0.0029 - val_loss: 0.0070
# Epoch 10/100
# 27/32 [========================>.....] - ETA: 0s - loss: 0.0014
# Epoch 10: val_loss did not improve from 0.00701
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0013 - val_loss: 0.0201
# Epoch 11/100
# 27/32 [========================>.....] - ETA: 0s - loss: 3.5067e-04
# Epoch 11: val_loss did not improve from 0.00701
# 32/32 [==============================] - 0s 11ms/step - loss: 3.2834e-04 - val_loss: 0.0226
# Epoch 12/100
# 31/32 [============================>.] - ETA: 0s - loss: 2.4969e-04
# Epoch 12: val_loss did not improve from 0.00701
# 32/32 [==============================] - 0s 11ms/step - loss: 2.5151e-04 - val_loss: 0.0083
# Epoch 13/100
# 31/32 [============================>.] - ETA: 0s - loss: 3.5598e-04
# Epoch 13: val_loss did not improve from 0.00701
# 32/32 [==============================] - 0s 11ms/step - loss: 3.5717e-04 - val_loss: 0.0076
# Epoch 14/100
# 32/32 [==============================] - ETA: 0s - loss: 3.6450e-04
# Epoch 14: val_loss improved from 0.00701 to 0.00645, saving model to /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl
# WARNING:absl:Found untraced functions such as lstm_cell_12_layer_call_fn, lstm_cell_12_layer_call_and_return_conditional_losses, lstm_cell_13_layer_call_fn, lstm_cell_13_layer_call_and_return_conditional_losses, lstm_cell_14_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7376369550> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7347a0d990> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7344e2ba90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 32/32 [==============================] - 20s 634ms/step - loss: 3.6450e-04 - val_loss: 0.0065
# Epoch 15/100
# 31/32 [============================>.] - ETA: 0s - loss: 3.3476e-04
# Epoch 15: val_loss improved from 0.00645 to 0.00451, saving model to /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl
# WARNING:absl:Found untraced functions such as lstm_cell_12_layer_call_fn, lstm_cell_12_layer_call_and_return_conditional_losses, lstm_cell_13_layer_call_fn, lstm_cell_13_layer_call_and_return_conditional_losses, lstm_cell_14_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7376369550> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7347a0d990> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7344e2ba90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 32/32 [==============================] - 18s 577ms/step - loss: 3.3548e-04 - val_loss: 0.0045
# Epoch 16/100
# 31/32 [============================>.] - ETA: 0s - loss: 3.2741e-04
# Epoch 16: val_loss improved from 0.00451 to 0.00308, saving model to /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl
# WARNING:absl:Found untraced functions such as lstm_cell_12_layer_call_fn, lstm_cell_12_layer_call_and_return_conditional_losses, lstm_cell_13_layer_call_fn, lstm_cell_13_layer_call_and_return_conditional_losses, lstm_cell_14_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7376369550> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7347a0d990> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7344e2ba90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 32/32 [==============================] - 16s 526ms/step - loss: 3.2747e-04 - val_loss: 0.0031
# Epoch 17/100
# 27/32 [========================>.....] - ETA: 0s - loss: 3.6536e-04
# Epoch 17: val_loss improved from 0.00308 to 0.00203, saving model to /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl
# WARNING:absl:Found untraced functions such as lstm_cell_12_layer_call_fn, lstm_cell_12_layer_call_and_return_conditional_losses, lstm_cell_13_layer_call_fn, lstm_cell_13_layer_call_and_return_conditional_losses, lstm_cell_14_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7376369550> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7347a0d990> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7344e2ba90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 32/32 [==============================] - 20s 650ms/step - loss: 3.2187e-04 - val_loss: 0.0020
# Epoch 18/100
# 28/32 [=========================>....] - ETA: 0s - loss: 3.4459e-04
# Epoch 18: val_loss improved from 0.00203 to 0.00125, saving model to /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl
# WARNING:absl:Found untraced functions such as lstm_cell_12_layer_call_fn, lstm_cell_12_layer_call_and_return_conditional_losses, lstm_cell_13_layer_call_fn, lstm_cell_13_layer_call_and_return_conditional_losses, lstm_cell_14_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7376369550> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7347a0d990> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7344e2ba90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 32/32 [==============================] - 23s 751ms/step - loss: 3.1392e-04 - val_loss: 0.0012
# Epoch 19/100
# 27/32 [========================>.....] - ETA: 0s - loss: 3.4744e-04
# Epoch 19: val_loss improved from 0.00125 to 0.00072, saving model to /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl
# WARNING:absl:Found untraced functions such as lstm_cell_12_layer_call_fn, lstm_cell_12_layer_call_and_return_conditional_losses, lstm_cell_13_layer_call_fn, lstm_cell_13_layer_call_and_return_conditional_losses, lstm_cell_14_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7376369550> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7347a0d990> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7344e2ba90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 32/32 [==============================] - 20s 650ms/step - loss: 3.0532e-04 - val_loss: 7.1534e-04
# Epoch 20/100
# 32/32 [==============================] - ETA: 0s - loss: 2.9627e-04
# Epoch 20: val_loss improved from 0.00072 to 0.00040, saving model to /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl
# WARNING:absl:Found untraced functions such as lstm_cell_12_layer_call_fn, lstm_cell_12_layer_call_and_return_conditional_losses, lstm_cell_13_layer_call_fn, lstm_cell_13_layer_call_and_return_conditional_losses, lstm_cell_14_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7376369550> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7347a0d990> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7344e2ba90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 32/32 [==============================] - 19s 599ms/step - loss: 2.9627e-04 - val_loss: 3.9611e-04
# Epoch 21/100
# 28/32 [=========================>....] - ETA: 0s - loss: 3.1593e-04
# Epoch 21: val_loss improved from 0.00040 to 0.00026, saving model to /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl
# WARNING:absl:Found untraced functions such as lstm_cell_12_layer_call_fn, lstm_cell_12_layer_call_and_return_conditional_losses, lstm_cell_13_layer_call_fn, lstm_cell_13_layer_call_and_return_conditional_losses, lstm_cell_14_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7376369550> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7347a0d990> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7344e2ba90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 32/32 [==============================] - 15s 486ms/step - loss: 2.8691e-04 - val_loss: 2.5576e-04
# Epoch 22/100
# 29/32 [==========================>...] - ETA: 0s - loss: 2.9627e-04
# Epoch 22: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 9ms/step - loss: 2.7739e-04 - val_loss: 2.6120e-04
# Epoch 23/100
# 26/32 [=======================>......] - ETA: 0s - loss: 3.1456e-04
# Epoch 23: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 10ms/step - loss: 2.6785e-04 - val_loss: 3.8061e-04
# Epoch 24/100
# 29/32 [==========================>...] - ETA: 0s - loss: 2.7621e-04
# Epoch 24: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 10ms/step - loss: 2.5845e-04 - val_loss: 5.8390e-04
# Epoch 25/100
# 28/32 [=========================>....] - ETA: 0s - loss: 2.7478e-04
# Epoch 25: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 10ms/step - loss: 2.4935e-04 - val_loss: 8.4333e-04
# Epoch 26/100
# 28/32 [=========================>....] - ETA: 0s - loss: 2.6513e-04
# Epoch 26: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 11ms/step - loss: 2.4070e-04 - val_loss: 0.0011
# Epoch 27/100
# 28/32 [=========================>....] - ETA: 0s - loss: 2.5610e-04
# Epoch 27: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 10ms/step - loss: 2.3265e-04 - val_loss: 0.0014
# Epoch 28/100
# 28/32 [=========================>....] - ETA: 0s - loss: 2.4787e-04
# Epoch 28: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 10ms/step - loss: 2.2536e-04 - val_loss: 0.0017
# Epoch 29/100
# 28/32 [=========================>....] - ETA: 0s - loss: 2.4058e-04
# Epoch 29: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 10ms/step - loss: 2.1894e-04 - val_loss: 0.0020
# Epoch 30/100
# 29/32 [==========================>...] - ETA: 0s - loss: 2.2714e-04
# Epoch 30: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 10ms/step - loss: 2.1347e-04 - val_loss: 0.0023
# Epoch 31/100
# 28/32 [=========================>....] - ETA: 0s - loss: 2.2925e-04
# Epoch 31: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 11ms/step - loss: 2.0901e-04 - val_loss: 0.0025
# Epoch 32/100
# 28/32 [=========================>....] - ETA: 0s - loss: 2.2526e-04
# Epoch 32: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 10ms/step - loss: 2.0553e-04 - val_loss: 0.0027
# Epoch 33/100
# 29/32 [==========================>...] - ETA: 0s - loss: 2.1541e-04
# Epoch 33: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 9ms/step - loss: 2.0297e-04 - val_loss: 0.0029
# Epoch 34/100
# 28/32 [=========================>....] - ETA: 0s - loss: 2.2026e-04
# Epoch 34: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 10ms/step - loss: 2.0120e-04 - val_loss: 0.0031
# Epoch 35/100
# 27/32 [========================>.....] - ETA: 0s - loss: 2.2657e-04
# Epoch 35: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 10ms/step - loss: 2.0008e-04 - val_loss: 0.0033
# Epoch 36/100
# 28/32 [=========================>....] - ETA: 0s - loss: 2.1819e-04
# Epoch 36: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 11ms/step - loss: 1.9944e-04 - val_loss: 0.0035
# Epoch 37/100
# 27/32 [========================>.....] - ETA: 0s - loss: 2.2540e-04
# Epoch 37: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 10ms/step - loss: 1.9915e-04 - val_loss: 0.0037
# Epoch 38/100
# 26/32 [=======================>......] - ETA: 0s - loss: 2.3156e-04
# Epoch 38: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 11ms/step - loss: 1.9910e-04 - val_loss: 0.0039
# Epoch 39/100
# 28/32 [=========================>....] - ETA: 0s - loss: 2.1785e-04
# Epoch 39: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 11ms/step - loss: 1.9922e-04 - val_loss: 0.0041
# Epoch 40/100
# 27/32 [========================>.....] - ETA: 0s - loss: 2.2563e-04
# Epoch 40: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 10ms/step - loss: 1.9945e-04 - val_loss: 0.0043
# Epoch 41/100
# 28/32 [=========================>....] - ETA: 0s - loss: 2.1839e-04
# Epoch 41: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 11ms/step - loss: 1.9977e-04 - val_loss: 0.0046
# Epoch 42/100
# 30/32 [===========================>..] - ETA: 0s - loss: 2.0592e-04
# Epoch 42: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 9ms/step - loss: 2.0015e-04 - val_loss: 0.0048
# Epoch 43/100
# 27/32 [========================>.....] - ETA: 0s - loss: 2.2679e-04
# Epoch 43: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 10ms/step - loss: 2.0059e-04 - val_loss: 0.0051
# Epoch 44/100
# 29/32 [==========================>...] - ETA: 0s - loss: 2.1287e-04
# Epoch 44: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 10ms/step - loss: 2.0108e-04 - val_loss: 0.0053
# Epoch 45/100
# 28/32 [=========================>....] - ETA: 0s - loss: 2.2021e-04
# Epoch 45: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 10ms/step - loss: 2.0162e-04 - val_loss: 0.0056
# Epoch 46/100
# 28/32 [=========================>....] - ETA: 0s - loss: 2.2078e-04
# Epoch 46: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 10ms/step - loss: 2.0221e-04 - val_loss: 0.0058
# Epoch 47/100
# 28/32 [=========================>....] - ETA: 0s - loss: 2.2141e-04
# Epoch 47: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 11ms/step - loss: 2.0284e-04 - val_loss: 0.0060
# Epoch 48/100
# 27/32 [========================>.....] - ETA: 0s - loss: 2.2979e-04
# Epoch 48: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 11ms/step - loss: 2.0353e-04 - val_loss: 0.0063
# Epoch 49/100
# 27/32 [========================>.....] - ETA: 0s - loss: 2.3054e-04
# Epoch 49: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 10ms/step - loss: 2.0428e-04 - val_loss: 0.0065
# Epoch 50/100
# 28/32 [=========================>....] - ETA: 0s - loss: 2.2358e-04
# Epoch 50: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 11ms/step - loss: 2.0508e-04 - val_loss: 0.0067
# Epoch 51/100
# 29/32 [==========================>...] - ETA: 0s - loss: 2.1744e-04
# Epoch 51: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 9ms/step - loss: 2.0595e-04 - val_loss: 0.0069
# Epoch 52/100
# 27/32 [========================>.....] - ETA: 0s - loss: 2.3315e-04
# Epoch 52: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 10ms/step - loss: 2.0688e-04 - val_loss: 0.0071
# Epoch 53/100
# 29/32 [==========================>...] - ETA: 0s - loss: 2.1924e-04
# Epoch 53: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 10ms/step - loss: 2.0787e-04 - val_loss: 0.0073
# Epoch 54/100
# 26/32 [=======================>......] - ETA: 0s - loss: 2.4165e-04
# Epoch 54: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 10ms/step - loss: 2.0893e-04 - val_loss: 0.0074
# Epoch 55/100
# 28/32 [=========================>....] - ETA: 0s - loss: 2.2842e-04
# Epoch 55: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 10ms/step - loss: 2.1007e-04 - val_loss: 0.0076
# Epoch 56/100
# 28/32 [=========================>....] - ETA: 0s - loss: 2.2960e-04
# Epoch 56: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 11ms/step - loss: 2.1127e-04 - val_loss: 0.0077
# Epoch 57/100
# 31/32 [============================>.] - ETA: 0s - loss: 2.1244e-04
# Epoch 57: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 11ms/step - loss: 2.1254e-04 - val_loss: 0.0078
# Epoch 58/100
# 28/32 [=========================>....] - ETA: 0s - loss: 2.3217e-04
# Epoch 58: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 10ms/step - loss: 2.1389e-04 - val_loss: 0.0079
# Epoch 59/100
# 28/32 [=========================>....] - ETA: 0s - loss: 2.3357e-04
# Epoch 59: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 10ms/step - loss: 2.1530e-04 - val_loss: 0.0080
# Epoch 60/100
# 28/32 [=========================>....] - ETA: 0s - loss: 2.3503e-04
# Epoch 60: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 11ms/step - loss: 2.1678e-04 - val_loss: 0.0080
# Epoch 61/100
# 27/32 [========================>.....] - ETA: 0s - loss: 2.4481e-04
# Epoch 61: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 10ms/step - loss: 2.1831e-04 - val_loss: 0.0080
# Epoch 62/100
# 27/32 [========================>.....] - ETA: 0s - loss: 2.4644e-04
# Epoch 62: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 11ms/step - loss: 2.1990e-04 - val_loss: 0.0080
# Epoch 63/100
# 27/32 [========================>.....] - ETA: 0s - loss: 2.4813e-04
# Epoch 63: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 10ms/step - loss: 2.2154e-04 - val_loss: 0.0080
# Epoch 64/100
# 26/32 [=======================>......] - ETA: 0s - loss: 2.5664e-04
# Epoch 64: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 10ms/step - loss: 2.2320e-04 - val_loss: 0.0080
# Epoch 65/100
# 27/32 [========================>.....] - ETA: 0s - loss: 2.5161e-04
# Epoch 65: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 11ms/step - loss: 2.2489e-04 - val_loss: 0.0080
# Epoch 66/100
# 27/32 [========================>.....] - ETA: 0s - loss: 2.5337e-04
# Epoch 66: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 11ms/step - loss: 2.2659e-04 - val_loss: 0.0080
# Epoch 67/100
# 26/32 [=======================>......] - ETA: 0s - loss: 2.6208e-04
# Epoch 67: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 10ms/step - loss: 2.2828e-04 - val_loss: 0.0079
# Epoch 68/100
# 28/32 [=========================>....] - ETA: 0s - loss: 2.4823e-04
# Epoch 68: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 10ms/step - loss: 2.2995e-04 - val_loss: 0.0079
# Epoch 69/100
# 28/32 [=========================>....] - ETA: 0s - loss: 2.4988e-04
# Epoch 69: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 10ms/step - loss: 2.3158e-04 - val_loss: 0.0078
# Epoch 70/100
# 28/32 [=========================>....] - ETA: 0s - loss: 2.5147e-04
# Epoch 70: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 10ms/step - loss: 2.3316e-04 - val_loss: 0.0078
# Epoch 71/100
# 28/32 [=========================>....] - ETA: 0s - loss: 2.5301e-04
# Epoch 71: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 10ms/step - loss: 2.3468e-04 - val_loss: 0.0077
# Epoch 72/100
# 27/32 [========================>.....] - ETA: 0s - loss: 2.6327e-04
# Epoch 72: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 10ms/step - loss: 2.3613e-04 - val_loss: 0.0076
# Epoch 73/100
# 29/32 [==========================>...] - ETA: 0s - loss: 2.4798e-04
# Epoch 73: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 11ms/step - loss: 2.3750e-04 - val_loss: 0.0075
# Epoch 74/100
# 31/32 [============================>.] - ETA: 0s - loss: 2.3851e-04
# Epoch 74: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 11ms/step - loss: 2.3878e-04 - val_loss: 0.0075
# Epoch 75/100
# 27/32 [========================>.....] - ETA: 0s - loss: 2.6727e-04
# Epoch 75: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 10ms/step - loss: 2.3997e-04 - val_loss: 0.0074
# Epoch 76/100
# 26/32 [=======================>......] - ETA: 0s - loss: 2.7590e-04
# Epoch 76: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 10ms/step - loss: 2.4109e-04 - val_loss: 0.0074
# Epoch 77/100
# 28/32 [=========================>....] - ETA: 0s - loss: 2.6055e-04
# Epoch 77: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 11ms/step - loss: 2.4212e-04 - val_loss: 0.0073
# Epoch 78/100
# 32/32 [==============================] - ETA: 0s - loss: 2.4308e-04
# Epoch 78: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 11ms/step - loss: 2.4308e-04 - val_loss: 0.0072
# Epoch 79/100
# 30/32 [===========================>..] - ETA: 0s - loss: 2.4787e-04
# Epoch 79: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 12ms/step - loss: 2.4396e-04 - val_loss: 0.0072
# Epoch 80/100
# 31/32 [============================>.] - ETA: 0s - loss: 2.4464e-04
# Epoch 80: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 11ms/step - loss: 2.4479e-04 - val_loss: 0.0071
# Epoch 81/100
# 30/32 [===========================>..] - ETA: 0s - loss: 2.4949e-04
# Epoch 81: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 12ms/step - loss: 2.4556e-04 - val_loss: 0.0071
# Epoch 82/100
# 29/32 [==========================>...] - ETA: 0s - loss: 2.5679e-04
# Epoch 82: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 12ms/step - loss: 2.4628e-04 - val_loss: 0.0070
# Epoch 83/100
# 31/32 [============================>.] - ETA: 0s - loss: 2.4686e-04
# Epoch 83: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 11ms/step - loss: 2.4696e-04 - val_loss: 0.0070
# Epoch 84/100
# 30/32 [===========================>..] - ETA: 0s - loss: 2.5158e-04
# Epoch 84: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 12ms/step - loss: 2.4760e-04 - val_loss: 0.0070
# Epoch 85/100
# 30/32 [===========================>..] - ETA: 0s - loss: 2.5220e-04
# Epoch 85: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 12ms/step - loss: 2.4822e-04 - val_loss: 0.0069
# Epoch 86/100
# 30/32 [===========================>..] - ETA: 0s - loss: 2.5280e-04
# Epoch 86: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 11ms/step - loss: 2.4880e-04 - val_loss: 0.0069
# Epoch 87/100
# 29/32 [==========================>...] - ETA: 0s - loss: 2.5989e-04
# Epoch 87: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 11ms/step - loss: 2.4936e-04 - val_loss: 0.0069
# Epoch 88/100
# 31/32 [============================>.] - ETA: 0s - loss: 2.4988e-04
# Epoch 88: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 12ms/step - loss: 2.4989e-04 - val_loss: 0.0068
# Epoch 89/100
# 31/32 [============================>.] - ETA: 0s - loss: 2.5041e-04
# Epoch 89: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 11ms/step - loss: 2.5041e-04 - val_loss: 0.0068
# Epoch 90/100
# 30/32 [===========================>..] - ETA: 0s - loss: 2.5494e-04
# Epoch 90: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 12ms/step - loss: 2.5090e-04 - val_loss: 0.0068
# Epoch 91/100
# 30/32 [===========================>..] - ETA: 0s - loss: 2.5543e-04
# Epoch 91: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 12ms/step - loss: 2.5137e-04 - val_loss: 0.0068
# Epoch 92/100
# 30/32 [===========================>..] - ETA: 0s - loss: 2.5589e-04
# Epoch 92: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 11ms/step - loss: 2.5183e-04 - val_loss: 0.0068
# Epoch 93/100
# 32/32 [==============================] - ETA: 0s - loss: 2.5226e-04
# Epoch 93: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 11ms/step - loss: 2.5226e-04 - val_loss: 0.0067
# Epoch 94/100
# 30/32 [===========================>..] - ETA: 0s - loss: 2.5677e-04
# Epoch 94: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 11ms/step - loss: 2.5268e-04 - val_loss: 0.0067
# Epoch 95/100
# 30/32 [===========================>..] - ETA: 0s - loss: 2.5718e-04
# Epoch 95: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 11ms/step - loss: 2.5308e-04 - val_loss: 0.0067
# Epoch 96/100
# 29/32 [==========================>...] - ETA: 0s - loss: 2.6405e-04
# Epoch 96: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 12ms/step - loss: 2.5346e-04 - val_loss: 0.0067
# Epoch 97/100
# 30/32 [===========================>..] - ETA: 0s - loss: 2.5794e-04
# Epoch 97: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 11ms/step - loss: 2.5382e-04 - val_loss: 0.0067
# Epoch 98/100
# 31/32 [============================>.] - ETA: 0s - loss: 2.5427e-04
# Epoch 98: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 11ms/step - loss: 2.5417e-04 - val_loss: 0.0067
# Epoch 99/100
# 31/32 [============================>.] - ETA: 0s - loss: 2.5461e-04
# Epoch 99: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 11ms/step - loss: 2.5450e-04 - val_loss: 0.0067
# Epoch 100/100
# 31/32 [============================>.] - ETA: 0s - loss: 2.5493e-04
# Epoch 100: val_loss did not improve from 0.00026
# 32/32 [==============================] - 0s 12ms/step - loss: 2.5481e-04 - val_loss: 0.0067
# CPU times: user 4min 59s, sys: 13.2 s, total: 5min 13s
# Wall time: 5min 25s

# %%
plt.figure(figsize=(20,8))
plt.plot(hist.history['loss'], label='train')
plt.plot(hist.history['val_loss'], label='val')
plt.legend()
plt.title("Mean squared error")
plt.show()

# %% [markdown]
# ## 4. Evaluation

# %%
loaded_model = load_model("/content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/lstm.pkl")

# %%
train_predicton = loaded_model.predict(X_train)
val_prediction = loaded_model.predict(X_val)

print("Train pred shape :", train_predicton.shape)
print("Val pred shape :", val_prediction.shape)
# Out:
# Train pred shape : (2016, 1)
# Val pred shape : (519, 1)

# %%
train_pred = scaler.inverse_transform(train_predicton)
val_pred = scaler.inverse_transform(val_prediction)
print(val_pred[:5])
# Out:
# [[76.45928 ]
#  [74.00001 ]
#  [73.02795 ]
#  [67.316795]
#  [72.09689 ]]

# %%
close = np.array(close)
cc = close.reshape((len(close), 1))
tt1, tt2 = cc[0:train_size,:], cc[train_size:len(close),:]
xtrain, ytrain = make_input(tt1, 1)
Xval, yval = make_input(tt2, 1)

# %%
val_rmse = math.sqrt(mean_squared_error(yval, val_pred))
print('Val RMSE: %.3f' % val_rmse)
# Out:
# Val RMSE: 2.688
