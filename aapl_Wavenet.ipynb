# %% [markdown]
# # AAPL price forecasting
# - This is an ipynb file created in colab environment.
# - Runtime : GPU
# - Wavenet

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
sys.path.append('/content/drive/MyDrive/Github/Time-series_price_analysis')

# %%
# !ls /content/drive/MyDrive/Github/Time-series_price_analysis/*.py
# Out:
# /content/drive/MyDrive/Github/Time-series_price_analysis/make_dataset.py

# %% [markdown]
# ## 0. Import Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import random as rn
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import ModelCheckpoint
from datetime import datetime

import keras.layers
from keras import optimizers
from keras.layers import Activation, Lambda, Input
from keras.layers import Conv1D, SpatialDropout1D, Flatten
from keras.layers import Convolution1D, Dense, Reshape
from keras.models import Input, Model
from typing import List, Tuple

import tensorflow as tf
import os

from make_dataset import time_transform, make_input

# %%
# reproducibility
seed_num = 42
rn.seed(seed_num)
tf.random.set_seed(seed_num)
os.environ['PYTHONHASHSEED']=str(seed_num)

from keras import backend as K
session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
K.set_session(sess)

# %% [markdown]
# ## 1. Load and visualize dataset

# %%
df = pd.read_csv("/content/drive/MyDrive/Github/Time-series_price_analysis/dataset/AAPL.csv")

# %%
df['Date'] = df['Date'].apply(lambda x: time_transform(x))
dataset = df.sort_values('Date').reset_index(drop=True)

# %%
print("Shape of dataset :", dataset.shape)
dataset.head()
# Out:
# Shape of dataset : (2539, 7)
#          Date  Price   Open   High    Low     Vol. Change %
# 0  2012-02-27  18.78  18.62  18.87  18.44  547.58M    0.64%
# 1  2012-02-28  19.12  18.86  19.12  18.78  600.39M    1.81%
# 2  2012-02-29  19.37  19.34  19.56  19.13  952.00M    1.31%
# 3  2012-03-01  19.45  19.58  19.58  19.24  683.25M    0.41%
# 4  2012-03-02  19.47  19.44  19.53  19.38  431.71M    0.10%

# %%
date = dataset['Date'].values
close = dataset['Price'].values

# %% [markdown]
# ## 2. Preprocessing

# %%
scaler = MinMaxScaler(feature_range=(0,1))
scaled_close = scaler.fit_transform(np.array(close).reshape(-1,1))

# %%
train_size = int(len(close)*0.795)
val_size = len(close)-train_size
train_data, val_data = scaled_close[0:train_size,:], scaled_close[train_size:len(close),:1]

# %%
time_step = 1
X_train, y_train = make_input(train_data, time_step)
X_val, y_val = make_input(val_data, time_step)

# %%
print("X train shape :", X_train.shape)
print("y train shape :", y_train.shape)
print("X val shape :", X_val.shape)
print("y val shape :", y_val.shape)
# Out:
# X train shape : (2016, 1)
# y train shape : (2016,)
# X val shape : (519, 1)
# y val shape : (519,)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1] , 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1] , 1)

print("X train shape :", X_train.shape)
print("X val shape :", X_val.shape)
# Out:
# X train shape : (2016, 1, 1)
# X val shape : (519, 1, 1)

# %% [markdown]
# ## 3. Modeling - Wavenet

# %%
def gated_activation_units(x):
    tanh_out = Activation('tanh')(x)
    sig_out = Activation('sigmoid')(x)
    return keras.layers.multiply([tanh_out, sig_out])


def residual_block(x, i, num_filters, kernel_size, padding):
    # i: The dilation power of 2


    prev_x = x
    conv = Conv1D(filters=num_filters, kernel_size = kernel_size, dilation_rate = i, padding = padding)(x) # dilated conv
    x = gated_activation_units(conv)  # gated activation units

    x = Convolution1D(num_filters, 1, padding='same')(x)  # skip connection

    res_x = keras.layers.add([prev_x, x])

    return res_x, x  # residual, skip connection

# %%
# params
dilations = [1, 2, 4, 8, 16, 32]
num_filters = 64
padding = "causal"
kernel_size = 2
num_stacks = 1

# %%
# wavenet
input = Input(shape=(X_train.shape[1], X_train.shape[2]))
x = Convolution1D(num_filters, 1, padding = padding)(input)  # causal conv

skip_connections = []
for k in range(num_stacks):
    for i in dilations:
        x, skip_out = residual_block(x, i, num_filters, kernel_size, padding)  # residual and skip connection
        skip_connections.append(skip_out)

x = keras.layers.add(skip_connections) 

x = Activation('relu')(x)

# Since then, different from original Wavenet

x = Dense(16, activation="relu")(x)
# x = Dropout(0.1)(x)
output = Dense(1)(x)

# %%
model = Model(inputs=input, outputs=output)
model.summary()
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_12 (InputLayer)          [(None, 1, 1)]       0           []
#
#  conv1d_126 (Conv1D)            (None, 1, 64)        128         ['input_12[0][0]']
#
#  conv1d_127 (Conv1D)            (None, 1, 64)        8256        ['conv1d_126[0][0]']
#
#  activation_121 (Activation)    (None, 1, 64)        0           ['conv1d_127[0][0]']
#
#  activation_122 (Activation)    (None, 1, 64)        0           ['conv1d_127[0][0]']
#
#  multiply_54 (Multiply)         (None, 1, 64)        0           ['activation_121[0][0]',
#                                                                   'activation_122[0][0]']
#
#  conv1d_128 (Conv1D)            (None, 1, 64)        4160        ['multiply_54[0][0]']
#
#  add_63 (Add)                   (None, 1, 64)        0           ['conv1d_126[0][0]',
#                                                                   'conv1d_128[0][0]']
#
#  conv1d_129 (Conv1D)            (None, 1, 64)        8256        ['add_63[0][0]']
#
#  activation_123 (Activation)    (None, 1, 64)        0           ['conv1d_129[0][0]']
#
#  activation_124 (Activation)    (None, 1, 64)        0           ['conv1d_129[0][0]']
#
#  multiply_55 (Multiply)         (None, 1, 64)        0           ['activation_123[0][0]',
#                                                                   'activation_124[0][0]']
#
#  conv1d_130 (Conv1D)            (None, 1, 64)        4160        ['multiply_55[0][0]']
#
#  add_64 (Add)                   (None, 1, 64)        0           ['add_63[0][0]',
#                                                                   'conv1d_130[0][0]']
#
#  conv1d_131 (Conv1D)            (None, 1, 64)        8256        ['add_64[0][0]']
#
#  activation_125 (Activation)    (None, 1, 64)        0           ['conv1d_131[0][0]']
#
#  activation_126 (Activation)    (None, 1, 64)        0           ['conv1d_131[0][0]']
#
#  multiply_56 (Multiply)         (None, 1, 64)        0           ['activation_125[0][0]',
#                                                                   'activation_126[0][0]']
#
#  conv1d_132 (Conv1D)            (None, 1, 64)        4160        ['multiply_56[0][0]']
#
#  add_65 (Add)                   (None, 1, 64)        0           ['add_64[0][0]',
#                                                                   'conv1d_132[0][0]']
#
#  conv1d_133 (Conv1D)            (None, 1, 64)        8256        ['add_65[0][0]']
#
#  activation_127 (Activation)    (None, 1, 64)        0           ['conv1d_133[0][0]']
#
#  activation_128 (Activation)    (None, 1, 64)        0           ['conv1d_133[0][0]']
#
#  multiply_57 (Multiply)         (None, 1, 64)        0           ['activation_127[0][0]',
#                                                                   'activation_128[0][0]']
#
#  conv1d_134 (Conv1D)            (None, 1, 64)        4160        ['multiply_57[0][0]']
#
#  add_66 (Add)                   (None, 1, 64)        0           ['add_65[0][0]',
#                                                                   'conv1d_134[0][0]']
#
#  conv1d_135 (Conv1D)            (None, 1, 64)        8256        ['add_66[0][0]']
#
#  activation_129 (Activation)    (None, 1, 64)        0           ['conv1d_135[0][0]']
#
#  activation_130 (Activation)    (None, 1, 64)        0           ['conv1d_135[0][0]']
#
#  multiply_58 (Multiply)         (None, 1, 64)        0           ['activation_129[0][0]',
#                                                                   'activation_130[0][0]']
#
#  conv1d_136 (Conv1D)            (None, 1, 64)        4160        ['multiply_58[0][0]']
#
#  add_67 (Add)                   (None, 1, 64)        0           ['add_66[0][0]',
#                                                                   'conv1d_136[0][0]']
#
#  conv1d_137 (Conv1D)            (None, 1, 64)        8256        ['add_67[0][0]']
#
#  activation_131 (Activation)    (None, 1, 64)        0           ['conv1d_137[0][0]']
#
#  activation_132 (Activation)    (None, 1, 64)        0           ['conv1d_137[0][0]']
#
#  multiply_59 (Multiply)         (None, 1, 64)        0           ['activation_131[0][0]',
#                                                                   'activation_132[0][0]']
#
#  conv1d_138 (Conv1D)            (None, 1, 64)        4160        ['multiply_59[0][0]']
#
#  add_69 (Add)                   (None, 1, 64)        0           ['conv1d_128[0][0]',
#                                                                   'conv1d_130[0][0]',
#                                                                   'conv1d_132[0][0]',
#                                                                   'conv1d_134[0][0]',
#                                                                   'conv1d_136[0][0]',
#                                                                   'conv1d_138[0][0]']
#
#  activation_133 (Activation)    (None, 1, 64)        0           ['add_69[0][0]']
#
#  dense_10 (Dense)               (None, 1, 16)        1040        ['activation_133[0][0]']
#
#  dense_11 (Dense)               (None, 1, 1)         17          ['dense_10[0][0]']
#
# ==================================================================================================
# Total params: 75,681
# Trainable params: 75,681
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
adam = Adam(learning_rate=0.001)
chk = ModelCheckpoint('/content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/wavenet.pkl', monitor = 'val_loss', save_best_only = True, mode = 'min', verbose = 1)

model.compile(loss='mse', optimizer = adam)

# %%
# %%time
hist = model.fit(X_train, y_train, validation_data=(X_val, y_val), callbacks=[chk], epochs=10, batch_size = 64, verbose = 1, shuffle = False)   # very fast
# Out:
# Epoch 1/30
# 31/32 [============================>.] - ETA: 0s - loss: 0.0010
# Epoch 1: val_loss improved from inf to 0.01028, saving model to /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/wavenet.pkl
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/wavenet.pkl/assets
# 32/32 [==============================] - 12s 209ms/step - loss: 0.0010 - val_loss: 0.0103
# Epoch 2/30
# 31/32 [============================>.] - ETA: 0s - loss: 0.0052
# Epoch 2: val_loss did not improve from 0.01028
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0053 - val_loss: 0.0439
# Epoch 3/30
# 31/32 [============================>.] - ETA: 0s - loss: 0.0038
# Epoch 3: val_loss did not improve from 0.01028
# 32/32 [==============================] - 1s 28ms/step - loss: 0.0038 - val_loss: 0.0288
# Epoch 4/30
# 31/32 [============================>.] - ETA: 0s - loss: 0.0057
# Epoch 4: val_loss did not improve from 0.01028
# 32/32 [==============================] - 1s 28ms/step - loss: 0.0058 - val_loss: 0.0205
# Epoch 5/30
# 31/32 [============================>.] - ETA: 0s - loss: 0.0026
# Epoch 5: val_loss did not improve from 0.01028
# 32/32 [==============================] - 1s 27ms/step - loss: 0.0026 - val_loss: 0.0155
# Epoch 6/30
# 30/32 [===========================>..] - ETA: 0s - loss: 0.0026
# Epoch 6: val_loss did not improve from 0.01028
# 32/32 [==============================] - 1s 27ms/step - loss: 0.0029 - val_loss: 0.1091
# Epoch 7/30
# 30/32 [===========================>..] - ETA: 0s - loss: 0.0044
# Epoch 7: val_loss did not improve from 0.01028
# 32/32 [==============================] - 1s 29ms/step - loss: 0.0052 - val_loss: 0.0601
# Epoch 8/30
# 31/32 [============================>.] - ETA: 0s - loss: 0.0039
# Epoch 8: val_loss improved from 0.01028 to 0.00773, saving model to /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/wavenet.pkl
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/wavenet.pkl/assets
# 32/32 [==============================] - 6s 185ms/step - loss: 0.0039 - val_loss: 0.0077
# Epoch 9/30
# 31/32 [============================>.] - ETA: 0s - loss: 0.0010
# Epoch 9: val_loss improved from 0.00773 to 0.00427, saving model to /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/wavenet.pkl
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/wavenet.pkl/assets
# 32/32 [==============================] - 6s 198ms/step - loss: 0.0010 - val_loss: 0.0043
# Epoch 10/30
# 31/32 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 10: val_loss did not improve from 0.00427
# 32/32 [==============================] - 1s 29ms/step - loss: 0.0016 - val_loss: 0.0066
# Epoch 11/30
# 31/32 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 11: val_loss did not improve from 0.00427
# 32/32 [==============================] - 1s 30ms/step - loss: 0.0024 - val_loss: 0.0525
# Epoch 12/30
# 31/32 [============================>.] - ETA: 0s - loss: 0.0030
# Epoch 12: val_loss did not improve from 0.00427
# 32/32 [==============================] - 1s 29ms/step - loss: 0.0035 - val_loss: 0.0911
# Epoch 13/30
# 30/32 [===========================>..] - ETA: 0s - loss: 0.0076
# Epoch 13: val_loss did not improve from 0.00427
# 32/32 [==============================] - 1s 29ms/step - loss: 0.0074 - val_loss: 0.0766
# Epoch 14/30
# 30/32 [===========================>..] - ETA: 0s - loss: 0.0054
# Epoch 14: val_loss did not improve from 0.00427
# 32/32 [==============================] - 1s 28ms/step - loss: 0.0080 - val_loss: 0.0641
# Epoch 15/30
# 30/32 [===========================>..] - ETA: 0s - loss: 0.0048
# Epoch 15: val_loss did not improve from 0.00427
# 32/32 [==============================] - 1s 27ms/step - loss: 0.0050 - val_loss: 0.1705
# Epoch 16/30
# 30/32 [===========================>..] - ETA: 0s - loss: 0.0047
# Epoch 16: val_loss did not improve from 0.00427
# 32/32 [==============================] - 1s 27ms/step - loss: 0.0048 - val_loss: 0.1753
# Epoch 17/30
# 31/32 [============================>.] - ETA: 0s - loss: 0.0068
# Epoch 17: val_loss did not improve from 0.00427
# 32/32 [==============================] - 1s 29ms/step - loss: 0.0073 - val_loss: 0.3886
# Epoch 18/30
# 30/32 [===========================>..] - ETA: 0s - loss: 0.0085
# Epoch 18: val_loss did not improve from 0.00427
# 32/32 [==============================] - 1s 27ms/step - loss: 0.0082 - val_loss: 0.0096
# Epoch 19/30
# 30/32 [===========================>..] - ETA: 0s - loss: 0.0020
# Epoch 19: val_loss did not improve from 0.00427
# 32/32 [==============================] - 1s 28ms/step - loss: 0.0020 - val_loss: 0.0222
# Epoch 20/30
# 30/32 [===========================>..] - ETA: 0s - loss: 0.0022
# Epoch 20: val_loss did not improve from 0.00427
# 32/32 [==============================] - 1s 27ms/step - loss: 0.0025 - val_loss: 0.0203
# Epoch 21/30
# 31/32 [============================>.] - ETA: 0s - loss: 0.0084
# Epoch 21: val_loss did not improve from 0.00427
# 32/32 [==============================] - 1s 29ms/step - loss: 0.0083 - val_loss: 0.0146
# Epoch 22/30
# 30/32 [===========================>..] - ETA: 0s - loss: 6.7033e-04
# Epoch 22: val_loss did not improve from 0.00427
# 32/32 [==============================] - 1s 28ms/step - loss: 8.0561e-04 - val_loss: 0.0212
# Epoch 23/30
# 30/32 [===========================>..] - ETA: 0s - loss: 0.0056
# Epoch 23: val_loss did not improve from 0.00427
# 32/32 [==============================] - 1s 29ms/step - loss: 0.0055 - val_loss: 0.0146
# Epoch 24/30
# 31/32 [============================>.] - ETA: 0s - loss: 0.0054
# Epoch 24: val_loss did not improve from 0.00427
# 32/32 [==============================] - 1s 30ms/step - loss: 0.0054 - val_loss: 0.0049
# Epoch 25/30
# 31/32 [============================>.] - ETA: 0s - loss: 9.0980e-04
# Epoch 25: val_loss did not improve from 0.00427
# 32/32 [==============================] - 1s 29ms/step - loss: 0.0011 - val_loss: 0.0891
# Epoch 26/30
# 31/32 [============================>.] - ETA: 0s - loss: 0.0048
# Epoch 26: val_loss did not improve from 0.00427
# 32/32 [==============================] - 1s 28ms/step - loss: 0.0055 - val_loss: 0.1234
# Epoch 27/30
# 30/32 [===========================>..] - ETA: 0s - loss: 0.0107
# Epoch 27: val_loss did not improve from 0.00427
# 32/32 [==============================] - 1s 27ms/step - loss: 0.0110 - val_loss: 0.3463
# Epoch 28/30
# 30/32 [===========================>..] - ETA: 0s - loss: 0.0093
# Epoch 28: val_loss did not improve from 0.00427
# 32/32 [==============================] - 1s 28ms/step - loss: 0.0107 - val_loss: 0.4389
# Epoch 29/30
# 30/32 [===========================>..] - ETA: 0s - loss: 0.0087
# Epoch 29: val_loss did not improve from 0.00427
# 32/32 [==============================] - 1s 28ms/step - loss: 0.0091 - val_loss: 0.2044
# Epoch 30/30
# 30/32 [===========================>..] - ETA: 0s - loss: 0.0097
# Epoch 30: val_loss did not improve from 0.00427
# 32/32 [==============================] - 1s 28ms/step - loss: 0.0105 - val_loss: 0.2517
# CPU times: user 46.6 s, sys: 1.89 s, total: 48.5 s
# Wall time: 49.2 s

# %% [markdown]
# ## 4. Evaluation

# %%
loaded_model = load_model("/content/drive/MyDrive/Github/Time-series_price_analysis/model_weights/aapl/wavenet.pkl")

# %%
train_predicton = loaded_model.predict(X_train)
val_prediction = loaded_model.predict(X_val)

train_predicton = np.reshape(train_predicton, (train_predicton.shape[0], 1))
val_prediction = np.reshape(val_prediction, (val_prediction.shape[0], 1))

print("Train pred shape :", train_predicton.shape)
print("Val pred shape :", val_prediction.shape)
# Out:
# Train pred shape : (2016, 1)
# Val pred shape : (519, 1)

# %%
train_pred = scaler.inverse_transform(train_predicton)
val_pred = scaler.inverse_transform(val_prediction)
print(val_pred[:5])
# Out:
# [[76.32148 ]
#  [73.7995  ]
#  [72.798355]
#  [66.9968  ]
#  [71.83712 ]]

# %%
close = np.array(close)
cc = close.reshape((len(close), 1))
tt1, tt2 = cc[0:train_size,:], cc[train_size:len(close),:]
xtrain, ytrain = make_input(tt1, 1)
Xval, yval = make_input(tt2, 1)

# %%
val_rmse = math.sqrt(mean_squared_error(yval, val_pred))
print('Val RMSE: %.3f' % val_rmse)
# Out:
# Val RMSE: 2.779
